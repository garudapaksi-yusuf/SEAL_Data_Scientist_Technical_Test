# %% [markdown]
# <h1 style='text-align: center'> SEAL Data Scientist Technical Test </h1>
# <h3 style='text-align: center; font-style: italic'> Oleh: Garudapaksi Yusuf </h3>
#
# ---
#
# ## 1 | *Table Creation*
#
# ### Data ETL
#
# [Extract, transform, load](https://en.wikipedia.org/wiki/Extract,_transform,_load) (ETL) adalah tiga fase pemrosesan data yang terdiri dari:
# 1. **Ekstraksi dari sumber data**: dalam *project* ini, secara langsung data diekstraksi dari *source* yang disediakan,
# 2. **Transformasi dalam format yang sesuai**: karena data tersedia dalam format `.csv` dan `xlsx` —dan untuk memudahkan proses analisa—, proses transformasi data akan menggunakan library Pandas untuk mengubah format data dalam bentuk DataFrame, dan
# 3. ***Load* ke data *container***: berupa *variable instance* dalam bahasa pemrograman Python.
#
# *Catatan:*
# * *Source data dan instruksi: [Google Drive](https://drive.google.com/drive/folders/16e052sYcXIIhrOVQJ86G_S12SGqrlp96?usp=sharing).*
# * *Dikutip dari `Data Scientist Techncial Test.xlsx` yang tersedia pada folder `docs` dari repository ini dengan sedikit modifikasi untuk memudahkan pemahaman.*
#
# > Buatlah *table* seperti berikut dari data dinas sosial dan data *master* desa:

# %%
# Import library yang dibutuhkan untuk mengakses contoh table
import pandas as pd

# Mengakses contoh table yang tersedia dalam format .xlsx
bentuk_table = pd.read_excel(
    io='../docs/Data Scientist Techncial Test.xlsx', # Letak dan nama file dari contoh table
    sheet_name='bentuk table', # Nama sheet dari contoh table
)

# %%
# Pengaturan untuk library Pandas 
pd.set_option(
    'display.max_columns', # Batasan untuk jumlah kolom yang ditampilkan
    None # Dihilangkan karena beberapa kolom disembunyikan dengan tampilan '...' 
)

# Menampilkan keseluruhan isi dari bentuk_table
bentuk_table
# Out:
#    id  kode_provinsi_y nama_provinsi  kode_kabupaten_kota  \
# 0   1               35    JAWA TIMUR                 3526
# 1   2               35    JAWA TIMUR                 3526
# 2   3               35    JAWA TIMUR                 3526
# 3   4               35    JAWA TIMUR                 3526
# 4   5               35    JAWA TIMUR                 3526
# 5   6               35    JAWA TIMUR                 3526
# 6   7               35    JAWA TIMUR                 3526
# 7   8               35    JAWA TIMUR                 3526
# 8   9               35    JAWA TIMUR                 3526
# 9  10               35    JAWA TIMUR                 3526
#
#              kabupaten  nama_kabupaten_kota  bps_kode_kecamatan    kecamatan  \
# 0  KABUPATEN BANGKALAN  KABUPATEN BANGKALAN             3526140        GEGER
# 1  KABUPATEN BANGKALAN  KABUPATEN BANGKALAN             3526070        GALIS
# 2  KABUPATEN BANGKALAN  KABUPATEN BANGKALAN             3526070        GALIS
# 3  KABUPATEN BANGKALAN  KABUPATEN BANGKALAN             3526140        GEGER
# 4  KABUPATEN BANGKALAN  KABUPATEN BANGKALAN             3526090       TRAGAH
# 5  KABUPATEN BANGKALAN  KABUPATEN BANGKALAN             3526010        KAMAL
# 6  KABUPATEN BANGKALAN  KABUPATEN BANGKALAN             3526020       LABANG
# 7  KABUPATEN BANGKALAN  KABUPATEN BANGKALAN             3526080  TANAH MERAH
# 8  KABUPATEN BANGKALAN  KABUPATEN BANGKALAN             3526120       BURNEH
# 9  KABUPATEN BANGKALAN  KABUPATEN BANGKALAN             3526140        GEGER
#
#   bps_nama_kecamatan  bps_kode_desa_kelurahan       kelurahan  \
# 0              GEGER               3526140002          LERPAK
# 1              GALIS               3526070004           GALIS
# 2              GALIS               3526070009         LONGKEK
# 3              GEGER               3526140006          CAMPOR
# 4             TRAGAH               3526090013          TRAGAH
# 5              KAMAL               3526010003       BANYUAJUH
# 6             LABANG               3526020003  SUKOLILO BARAT
# 7        TANAH MERAH               3526080022           POTER
# 8             BURNEH               3526120003          BURNEH
# 9              GEGER               3526140012  BANYONENG LAOK
#
#   bps_nama_desa_kelurahan kemendagri_kode_kecamatan kemendagri_nama_kecamatan  \
# 0                  LERPAK                  35.26.06                     GEGER
# 1                   GALIS                  35.26.18                     GALIS
# 2                 LONGKEK                  35.26.18                     GALIS
# 3                  CAMPOR                  35.26.06                     GEGER
# 4                  TRAGAH                  35.26.14                    TRAGAH
# 5              BANYU AJUH                  35.26.04                     KAMAL
# 6          SUKOLILO BARAT                  35.26.12                    LABANG
# 7                   POTER                  35.26.13               TANAH MERAH
# 8                  BURNEH                  35.26.03                    BURNEH
# 9          BANYONENG LAOK                  35.26.06                     GEGER
#
#   kemendagri_kode_desa_kelurahan kemendagri_nama_desa_kelurahan  \
# 0                  35.26.06.2005                         LERPAK
# 1                  35.26.18.2007                          GALIS
# 2                  35.26.18.2006                        LONGKEK
# 3                  35.26.06.2010                         CAMPOR
# 4                  35.26.14.2006                         TRAGAH
# 5                  35.26.04.2002                      BANYUAJUH
# 6                  35.26.12.2006                 SUKOLILO BARAT
# 7                  35.26.13.2014                          POTER
# 8                  35.26.03.2001                         BURNEH
# 9                  35.26.06.2002                 BANYONENG LAOK
#
#     periode_update               nik                    nama  \
# 0  TRIWULAN I 2024  3526060000000000               ABD HALIM
# 1  TRIWULAN I 2024  3526180000000000             ABD. ROHMAN
# 2  TRIWULAN I 2024  3526190000000000            ABDUS SYUKUR
# 3  TRIWULAN I 2024  3526060000000000                  ACHMAD
# 4  TRIWULAN I 2024  3526140000000000            ACHMAD RIDOI
# 5  TRIWULAN I 2024  3526040000000000            ALFIN MASKUR
# 6  TRIWULAN I 2024  3526130000000000             AMANIA ALIA
# 7  TRIWULAN I 2024  3526130000000000  ANDRIAN SAKBAN PURNOMO
# 8  TRIWULAN I 2024  3526030000000000   ANDRIANTA WALIYUDDINS
# 9  TRIWULAN I 2024  3526060000000000                   ANWAR
#
#                alamat  kategori kategori.1 jumlah satuan  tahun
# 0         DSN GLIMBUR       NaN          -      -      -   2024
# 1   DSN. REMBAH GALIS       NaN          -      -      -   2024
# 2   DSN. BARAT SUMBER       NaN          -      -      -   2024
# 3          DSN POCONG       NaN          -      -      -   2024
# 4      DSN. BANGGUMOK       NaN          -      -      -   2024
# 5    JL. AKH. KUSAIRI       NaN          -      -      -   2024
# 6      DSN. TENGGINAH       NaN          -      -      -   2024
# 7           DSN. SABE       NaN          -      -      -   2024
# 8         JL. MANGGIS       NaN          -      -      -   2024
# 9  DSN. SUMBER GUDANG       NaN          -      -      -   2024

# %% [markdown]
# *Catatan*:
# * *Indeks tabel yang ditampilkan mulai dari `0-4` pada contoh tabel di atas adalah indeks yang ditampilkan dari Pandas (menggunakan sistem [0-indexing](https://pandas.pydata.org/docs/user_guide/indexing.html) yang dimulai dari angka 0), sedangkan*
# * *Kolom `id` dengan nilai yang hampir serupa —mulai dari `1-5`— merupakan indeks yang disediakan dari `bentuk_table`.*
#
# Berikutnya, `bentuk_table` di atas akan dibandingkan dengan data dinas sosial dan data *master* desa yang tersedia pada folder `data`:

# %%
# Mengakses data dinas sosial dalam format .csv
data_dinsos_csv = pd.read_csv(
    filepath_or_buffer='../data/Data Dinas Sosial.csv',
    sep=';', # Character yang digunakan sebagai delimiter/separator
)

# Dan dalam format .xlsx
data_dinsos_xlsx = pd.read_excel(
    io='../data/Data Dinas Sosial.xlsx',
)

# Mengakses data master desa
data_master_desa = pd.read_csv(
    filepath_or_buffer='../data/masterdesa.csv',
    sep=';'
)

# %%
# Menampilkan 5 baris pertama dari 'Data Dinas Sosial.csv'
data_dinsos_csv.head(
    n=5
)
# Out:
#    id  kode_provinsi nama_provinsi   periode_update          nik  \
# 0   1             35    Jawa Timur  Triwulan I 2024  3,52606E+15
# 1   2             35    Jawa Timur  Triwulan I 2024  3,52618E+15
# 2   3             35    Jawa Timur  Triwulan I 2024  3,52619E+15
# 3   4             35    Jawa Timur  Triwulan I 2024  3,52606E+15
# 4   5             35    Jawa Timur  Triwulan I 2024  3,52614E+15
#
#            nama             alamat    provinsi       kabupaten kecamatan  \
# 0     ABD HALIM        DSN GLIMBUR  JAWA TIMUR  KAB. BANGKALAN     GEGER
# 1   ABD. ROHMAN  DSN. REMBAH GALIS  JAWA TIMUR  KAB. BANGKALAN     GALIS
# 2  ABDUS SYUKUR  DSN. BARAT SUMBER  JAWA TIMUR  KAB. BANGKALAN     GALIS
# 3        ACHMAD         DSN POCONG  JAWA TIMUR  KAB. BANGKALAN     GEGER
# 4  ACHMAD RIDOI     DSN. BANGGUMOK  JAWA TIMUR  KAB. BANGKALAN    TRAGAH
#
#   kelurahan  tahun kategori jumlah satuan
# 0    LERPAK   2024        -      -      -
# 1     GALIS   2024        -      -      -
# 2   LONGKEK   2024        -      -      -
# 3    CAMPOR   2024        -      -      -
# 4    TRAGAH   2024        -      -      -

# %%
# Menampilkan 5 baris pertama dari 'Data Dinas Sosial.xlsx'
data_dinsos_xlsx.head(
    n=5
)
# Out:
#    id  kode_provinsi nama_provinsi   periode_update                    nik  \
# 0   1             35    Jawa Timur  Triwulan I 2024  352606000000000000000
# 1   2             35    Jawa Timur  Triwulan I 2024  352618000000000000000
# 2   3             35    Jawa Timur  Triwulan I 2024  352619000000000032768
# 3   4             35    Jawa Timur  Triwulan I 2024  352606000000000000000
# 4   5             35    Jawa Timur  Triwulan I 2024  352614000000000000000
#
#            nama             alamat    provinsi       kabupaten kecamatan  \
# 0     ABD HALIM        DSN GLIMBUR  JAWA TIMUR  KAB. BANGKALAN     GEGER
# 1   ABD. ROHMAN  DSN. REMBAH GALIS  JAWA TIMUR  KAB. BANGKALAN     GALIS
# 2  ABDUS SYUKUR  DSN. BARAT SUMBER  JAWA TIMUR  KAB. BANGKALAN     GALIS
# 3        ACHMAD         DSN POCONG  JAWA TIMUR  KAB. BANGKALAN     GEGER
# 4  ACHMAD RIDOI     DSN. BANGGUMOK  JAWA TIMUR  KAB. BANGKALAN    TRAGAH
#
#   kelurahan  tahun kategori jumlah satuan
# 0    LERPAK   2024        -      -      -
# 1     GALIS   2024        -      -      -
# 2   LONGKEK   2024        -      -      -
# 3    CAMPOR   2024        -      -      -
# 4    TRAGAH   2024        -      -      -

# %% [markdown]
# **Observasi:**
#
# Sekilas tampak bahwa isi dari kedua format dari data dinas sosial `dinsos` pada tiap kolom hampir serupa.
# * Kecuali pada kolom `nik` yang ditampilkan dalam format *scientific* (menggunakan notasi `E` untuk menampilkan bilangan numerik) pada `dinsos_csv`, dan menggunakan format numerik pada `dinsos_xlsx`.
# * Untuk memudahkan perbandingan, tahapan berikutnya akan mengubah nilai `nik` pada `dinsos_csv` ke dalam format numerik.

# %% [markdown]
# #### Data Transformation

# %% [markdown]
# Sebelum proses transformasi tersebut dimulai, pertama-tama perlu dilihat terlebih dahulu nilai-nilai yang ada pada kolom tersebut:

# %%
# Menunjukkan nilai unik pada kolom 'nik' dalam `dinsos_csv`
data_dinsos_csv['nik'].unique()
# Out:
# array(['3,52606E+15', '3,52618E+15', '3,52619E+15', '3,52614E+15',
#        '3,52604E+15', '3,52613E+15', '3,52603E+15', '3,52608E+15',
#        '3,52607E+15', '3,5261E+15', '3,52601E+15', '3,52605E+15',
#        '3,57805E+15', '3,52616E+15', '3,57804E+15', '3,52612E+15',
#        '3,52617E+15', '3,52666E+15', '3,51324E+15', '3,52602E+15',
#        '3,51019E+15', '3,51005E+15', '3,51016E+15', '3,51007E+15',
#        '3,52211E+15', '3,51006E+15', '3,51021E+15', '3,51012E+15',
#        '3,51003E+15', '3,51017E+15', '3,51009E+15', '3,51022E+15',
#        '3,51014E+15', '3,51011E+15', '3,5102E+15', '3,51013E+15',
#        '3,51001E+15', '3,51024E+15', '3,51015E+15', '3,51008E+15',
#        '3,51002E+15', '3,51004E+15', '3,5101E+15', '3,51518E+15',
#        '3,50502E+15', '3,50507E+15', '3,50505E+15', '3,50503E+15',
#        '3,50509E+15', '3,50516E+15', '3,50508E+15', '3,50504E+15',
#        '3,50518E+15', '3,50506E+15', '3,5051E+15', '3,50519E+15',
#        '3,50306E+15', '3,50601E+15', '3,5222E+15', '3,52204E+15',
#        '3,52202E+15', '3,52212E+15', '3,52219E+15', '3,52215E+15',
#        '3,52206E+15', '3,52214E+15', '3,52213E+15', '3,52225E+15',
#        '3,52228E+15', '3,52209E+15', '3,52208E+15', '3,52205E+15',
#        '3,52224E+15', '3,52201E+15', '3,5221E+15', '3,52203E+15',
# * Ditemukan juga beberapa format lain seperti `` `3527035109120002 `` dan `'3503125502060001`.
#
# Untuk menyesuaikan nilai-nilai tersebut dengan notasi *scientific* yang umumnya berlaku, maka karakter-karakter berikut perlu dimodifikasi:

# %%
# Mengganti karakter tertentu pada kolom 'nik' dalam 'data_dinsos_csv' 
data_dinsos_csv['nik'] = data_dinsos_csv['nik'].replace(
    to_replace={
        ',': '.',
        '`': '',
        "'": ''
    },
    regex=True # Mengimplementasikan regular expression pada parameter 'to_replace'
)

# %% [markdown]
# Setelah menggunakan format yang sesuai, nilai-nilai yang masih menggunakan tipe data *object* dapat dikonversi ke dalam tipe data *numeric*:

# %%
# Mengonversi tipe data pada kolom 'nik' dalam 'data_dinsos_csv'
data_dinsos_csv['nik'] = pd.to_numeric( # Ke tipe data numeric
    arg=data_dinsos_csv['nik']
)

print(f"Tipe data pada kolom 'nik' dalam 'data_dinsos_csv': {data_dinsos_csv['nik'].dtype}")
# Out:
# Tipe data pada kolom 'nik' dalam 'data_dinsos_csv': float64

# %% [markdown]
# Terakhir, nilai yang sudah menggunakan tipe data *numeric* namun dalam bentuk `float` diubah menjadi `int`:

# %%
# Mengubah tipe data pada kolom 'nik' dalam 'data_dinsos_csv'
data_dinsos_csv['nik'] = data_dinsos_csv['nik'].astype( 
    dtype=int # Menjadi tipe data 'int'
)

# %% [markdown]
# Berikut ditunjukkan hasil dari transformasi data pada kolom `nik` dalam `data_dinsos_csv`:

# %%
data_dinsos_csv['nik'].unique()
# Out:
# array([ 3526060000000000,  3526180000000000,  3526190000000000,
#         3526140000000000,  3526040000000000,  3526130000000000,
#         3526030000000000,  3526080000000000,  3526070000000000,
#         3526100000000000,  3526010000000000,  3526050000000000,
#         3578050000000000,  3526160000000000,  3578040000000000,
#         3526120000000000,  3526170000000000,  3526660000000000,
#         3513240000000000,  3526020000000000,  3510190000000000,
#         3510050000000000,  3510160000000000,  3510070000000000,
#         3522110000000000,  3510060000000000,  3510210000000000,
#         3510120000000000,  3510030000000000,  3510170000000000,
#         3510090000000000,  3510220000000000,  3510140000000000,
#         3510110000000000,  3510200000000000,  3510130000000000,
#         3510010000000000,  3510240000000000,  3510150000000000,
#         3510080000000000,  3510020000000000,  3510040000000000,
#         3510100000000000,  3515180000000000,  3505020000000000,
#         3505070000000000,  3505050000000000,  3505030000000000,
#         3505090000000000,  3505160000000000,  3505080000000000,
#         3505040000000000,  3505180000000000,  3505060000000000,
#         3505100000000000,  3505190000000000,  3503060000000000,
#         3506010000000000,  3522200000000000,  3522040000000000,
#         3522020000000000,  3522120000000000,  3522190000000000,
#         3522150000000000,  3522060000000000,  3522140000000000,
#         3522130000000000,  3522250000000000,  3522280000000000,
#         3522090000000000,  3522080000000000,  3522050000000000,
#         3522240000000000,  3522010000000000,  3522100000000000,
#         3522030000000000,  3522270000000000,  3522160000000000,
#         3522220000000000,  3522070000000000,  3209310000000000,
#         3522230000000000,  6473010000000000,  3522210000000000,
#         3522290000000000,  3511030000000000,  3511210000000000,
#         3672050000000000,  3512100000000000,  3512050000000000,
#         3529020000000000,  3529120000000000,  3529100000000000,
#         3529080000000000,  3529130000000000,  3529110000000000,
#         3529030000000000,  3529090000000000,  3529040000000000,
#         3529200000000000,  3529060000000000,  2101160000000000,
#         3529180000000000,  3529170000000000,  3529160000000000,
#         3529050000000000,  3529070000000000,  3529260000000000,
#         3503010000000000,  3503080000000000,  3503040000000000,
#         3503090000000000,  3503130000000000,  3503050000000000,
#         3503120000000000,  3503030000000000,  3503070000000000,
#         3503020000000000,  3503110000000000,  3503140000000000,
#         3303180000000000,  3503125502060001,  3523170000000000,
#         3523010000000000,  3523110000000000,  3523070000000000,
#         3523080000000000,  3523160000000000,  3514100000000000,
#         3523150000000000,  6402130000000000,  3523030000000000,
#         3523140000000000,  3523100000000000,  3523090000000000,
#         3523210000000000,  3523130000000000,  3523180000000000,
#         3523200000000000,  1223040000000000,  3523020000000000,
#         3523190000000000,  3504110000000000,  3504030000000000,
#         3504150000000000,  3504050000000000,  3504140000000000,
#         3604090000000000,  3504100000000000,  3504090000000000,
#         3504060000000000,  3504040000000000,  3504010000000000,
#         3504190000000000,  3504020000000000,  3504180000000000,
#         3504080000000000,  3504130000000000,  3504070000000000,
#         3504120000000000,  3504170000000000,  3306040000000000])

# %% [markdown]
# Data tersebut dapat dibandingkan dengan data serupa yang tersedia pada `data_dinsos_xlsx` dan `bentuk_table` sebagai acuan format yang hendak digunakan:

# %%
pd.DataFrame(
    data=[
        len(bentuk_table['nik'].astype(str)[0]),
        len(data_dinsos_csv['nik'].astype(str)[0]),
        len(data_dinsos_xlsx['nik'].astype(str)[0])
    ],
    index=[
        'nik_table',
        'nik_csv',
        'nik_xlsx'
    ],
    columns=[
        'len()'
    ]
)
# Out:
#            len()
# nik_table     16
# nik_csv       16
# nik_xlsx      21

# %% [markdown]
# *Catatan:*
#
# *Fungsi `len()` digunakan untuk menghitung panjang atau jumlah item dalam suatu object.*
# * *Ketika object tersebut berwujud string, maka fungsi ini akan menghitung jumlah karakter dalam string tersebut.*
# * *Sehingga kolom `nik` perlu diubah tipe datanya terlebih dahulu menjadi `str`.*
# * *Data pertama pada kolom ini diakses dengan integer-based indexing `[0]` untuk kemudian dihitung panjang datanya dengan `len()`.*
#
# *Dengan kata lain, fungsi ini menghitung jumlah digit dari data kolom `nik` pada tiap sumber data*
#
# **Observasi:**
#
# Nilai `nik` pada `data_dinsos_csv` adalah yang paling sesuai:
# * Karena panjang datanya serupa dengan yang telah dicontohkan pada `bentuk_table`, dan
# * Secara *domain knowledge* yang umum diketahui, `nik` atau Nomor Induk Kependudukan terdiri dari 16 digit angka.

# %% [markdown]
# #### ETL Finalization

# %% [markdown]
# Berdasarkan penemuan di atas, diputuskan untuk menggunakan `dinsos.csv` sebagai format yang representatif untuk data dinas sosial. Juga ditampilkan sumber data lainnya yakni data master desa.

# %%
# Membuat variable instance baru 
data_dinas_sosial = data_dinsos_csv # Dari format data dinas sosial yang akan digunakan

data_dinas_sosial.head(
    n=5
)
# Out:
#    id  kode_provinsi nama_provinsi   periode_update               nik  \
# 0   1             35    Jawa Timur  Triwulan I 2024  3526060000000000
# 1   2             35    Jawa Timur  Triwulan I 2024  3526180000000000
# 2   3             35    Jawa Timur  Triwulan I 2024  3526190000000000
# 3   4             35    Jawa Timur  Triwulan I 2024  3526060000000000
# 4   5             35    Jawa Timur  Triwulan I 2024  3526140000000000
#
#            nama             alamat    provinsi       kabupaten kecamatan  \
# 0     ABD HALIM        DSN GLIMBUR  JAWA TIMUR  KAB. BANGKALAN     GEGER
# 1   ABD. ROHMAN  DSN. REMBAH GALIS  JAWA TIMUR  KAB. BANGKALAN     GALIS
# 2  ABDUS SYUKUR  DSN. BARAT SUMBER  JAWA TIMUR  KAB. BANGKALAN     GALIS
# 3        ACHMAD         DSN POCONG  JAWA TIMUR  KAB. BANGKALAN     GEGER
# 4  ACHMAD RIDOI     DSN. BANGGUMOK  JAWA TIMUR  KAB. BANGKALAN    TRAGAH
#
#   kelurahan  tahun kategori jumlah satuan
# 0    LERPAK   2024        -      -      -
# 1     GALIS   2024        -      -      -
# 2   LONGKEK   2024        -      -      -
# 3    CAMPOR   2024        -      -      -
# 4    TRAGAH   2024        -      -      -

# %%
# Menampilkan 5 baris pertama dari data master desa
data_master_desa.head(
    n=5
)
# Out:
#    kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0             35    JAWA TIMUR                 3501   KABUPATEN PACITAN
# 1             35    JAWA TIMUR                 3501   KABUPATEN PACITAN
# 2             35    JAWA TIMUR                 3501   KABUPATEN PACITAN
# 3             35    JAWA TIMUR                 3501   KABUPATEN PACITAN
# 4             35    JAWA TIMUR                 3501   KABUPATEN PACITAN
#
#    bps_kode_kecamatan bps_nama_kecamatan  bps_kode_desa_kelurahan  \
# 0             3501010           DONOROJO               3501010001
# 1             3501010           DONOROJO               3501010002
# 2             3501010           DONOROJO               3501010003
# 3             3501010           DONOROJO               3501010004
# 4             3501010           DONOROJO               3501010005
#
#   bps_desa_kelurahan kemendagri_kode_kecamatan kemendagri_nama_kecamatan  \
# 0             WIDORO                  35.01.01                  DONOROJO
# 1            SAWAHAN                  35.01.01                  DONOROJO
# 2              KALAK                  35.01.01                  DONOROJO
# 3            SENDANG                  35.01.01                  DONOROJO
# 4              KLEPU                  35.01.01                  DONOROJO
#
#   kemendagri_kode_desa_kelurahan kemendagri_desa_kelurahan
# 0                  35.01.01.2001                    WIDORO
# 1                  35.01.01.2002                   SAWAHAN
# 2                  35.01.01.2003                     KALAK
# 3                  35.01.01.2004                   SENDANG
# 4                  35.01.01.2005                     KLEPU

# %% [markdown]
# Setelah proses ETL berhasil dilakukan, data tersebut dibandingkan dengan `bentuk_table` yang disediakan untuk membuat *table* dengan format yang sesuai.

# %% [markdown]
# ### Data Comparison

# %% [markdown]
# Berikut disertakan DataFrame yang berisikan daftar nama kolom pada `bentuk_table` dengan `data_dinas_sosial` dan `data_master_desa`:

# %%
pd.DataFrame(
    # Label/nama kolom pada tiap data
    data=[
        bentuk_table.columns, 
        data_dinas_sosial.columns,
        data_master_desa.columns
    ],
    # Indeks untuk tiap daftar nama kolom
    index=[
        'bentuk_table',
        'data_dinas_sosial',
        'data_master_desa'
    ]
).T # Transpose DataFrame untuk memudahkan analisis
# Out:
#                       bentuk_table data_dinas_sosial  \
# 0                               id                id
# 1                  kode_provinsi_y     kode_provinsi
# 2                    nama_provinsi     nama_provinsi
# 3              kode_kabupaten_kota    periode_update
# 4                        kabupaten               nik
# 5              nama_kabupaten_kota              nama
# 6               bps_kode_kecamatan            alamat
# 7                        kecamatan          provinsi
# 8               bps_nama_kecamatan         kabupaten
# 9          bps_kode_desa_kelurahan         kecamatan
# 10                       kelurahan         kelurahan
# 11         bps_nama_desa_kelurahan             tahun
# 12       kemendagri_kode_kecamatan          kategori
# 13       kemendagri_nama_kecamatan            jumlah
# 14  kemendagri_kode_desa_kelurahan            satuan
# 15  kemendagri_nama_desa_kelurahan              None
# 16                  periode_update              None
# 17                             nik              None
# 18                            nama              None
# 19                          alamat              None
# 20                        kategori              None
# 21                      kategori.1              None
# 22                          jumlah              None
# 23                          satuan              None
# 24                           tahun              None
#
#                   data_master_desa
# 0                    kode_provinsi
# 1                    nama_provinsi
# 2              kode_kabupaten_kota
# 3              nama_kabupaten_kota
# 4               bps_kode_kecamatan
# 5               bps_nama_kecamatan
# 6          bps_kode_desa_kelurahan
# 7               bps_desa_kelurahan
# 8        kemendagri_kode_kecamatan
# 9        kemendagri_nama_kecamatan
# 10  kemendagri_kode_desa_kelurahan
# 11       kemendagri_desa_kelurahan
# 12                            None
# 13                            None
# 14                            None
# 15                            None
# 16                            None
# 17                            None
# 18                            None
# 19                            None
# 20                            None
# 21                            None
# 22                            None
# 23                            None
# 24                            None

# %% [markdown]
# **Observasi:**
# * Beberapa kolom yang dibutuhkan untuk membuat *table* sesuai acuan dari `bentuk_table` hanya ditemukan persis satu di `data_dinas_sosial` maupun `data_master_desa`.
#     * Seperti kolom `id`, `kode_kabupaten_kota`, dan `bps_kode_kecamatan`.
#     * Sehingga terdapat kemungkinan untuk melakukan penggabungan atau *merge* dari dua sumber data ini.
# * Namun proses penggabungan DataFrame membutuhkan *key*: data beserta kolomnya yang identik pada DataFrame yang hendak digabungkan.
#     * Meskipun kedua kolom `kode_provinsi` pada masing-masing sumber data identik, tetapi `bentuk_table` menunjukkan bahwa `kode_provinsi` yang digunakan memiliki imbuhan `_y` —menandakan bahwa kolom ini berasal dari DataFrame kedua yang hendak digabungkan—, sehingga kolom ini tidak dijadikan *key* untuk membuat tabel baru.
#     * *Merge umumnya menambahkan imbuhan di akhir nama kolom untuk dua kolom dengan nama yang sama dan akan digabungkan, sehingga imbuhan tersebut menandakan dari DataFrame mana asalnya.*
#     * Dengan demikian, kolom yang akan ditentukan sebagai `key` adalah:
#         1. Kolom `nama_provinsi`,
#         2. Pasangan kolom `kabupaten` dan `nama_kabupaten_kota`,
#         3. Antara `kecamatan` dengan `bps_nama_kecamatan` atau `kemendagri_nama_kecamatan`, dan
#         4. Antara `kelurahan` dengan `bps_desa_kelurahan` atau `kemendagri_nama_desa_kelurahan`.
#     * Khusus untuk nomor 3 dan 4, analisis berikut akan menentukan pasangan kolom mana yang akan digunakan sebagai `key` berikutnya:

# %%
# Jumlah dari elemen dalam kolom 'kecamatan' dan 'kelurahan'
kecamatan_len = len(data_dinas_sosial['kecamatan'])
kelurahan_len = len(data_dinas_sosial['kelurahan'])

# Jumlah dari elemen tiap kolom yang berada pada kolom 'bps_' dan 'kemendagri'
kecamatan_bps_len = len(data_dinas_sosial[data_dinas_sosial['kecamatan'].isin(values=data_master_desa['bps_nama_kecamatan'])])
kelurahan_bps_len = len(data_dinas_sosial[data_dinas_sosial['kelurahan'].isin(values=data_master_desa['bps_desa_kelurahan'])])
kecamatan_kemendagri_len = len(data_dinas_sosial[data_dinas_sosial['kecamatan'].isin(values=data_master_desa['kemendagri_nama_kecamatan'])])
kelurahan_kemendagri_len = len(data_dinas_sosial[data_dinas_sosial['kelurahan'].isin(values=data_master_desa['kemendagri_desa_kelurahan'])])

pd.DataFrame(
    data=[
        (kecamatan_len, kelurahan_len),
        (kecamatan_bps_len, kelurahan_bps_len),
        (kecamatan_kemendagri_len, kelurahan_kemendagri_len)
    ],
    index=[
        'len()',
        'isin(bps_)',
        'isin(kemendagri_)'
    ],
    # Nama untuk tiap kolom pada DataFrame instance berikut
    columns=[
        'kecamatan',
        'kelurahan'
    ]
)
# Out:
#                    kecamatan  kelurahan
# len()                  11583      11583
# isin(bps_)             10853      10713
# isin(kemendagri_)      11387      11545

# %% [markdown]
# **Observasi:**
#
# Jumlah elemen dari tiap kolom `kecamatan` dan `kelurahan` yang persis sama dengan elemen pada kolom `bps_` lebih sedikit daripada kolom `kemendagri_`.
# * Hal tersebut nantinya berdampak pada jumlah *missing value* yang lebih banyak jika menggabungkan masing-masing kolom dengan `bps_`.
# * Dengan mempertimbangkan prinsip [kualitas data](https://en.wikipedia.org/wiki/Data_quality) yang membandingkan antara kondisi data saat ini dengan kondisi yang dikehendaki —salah satunya adalah *free of defect*—, maka kolom `kemendagri_` yang akan digunakan sebagai key pada tahapan berikutnya untuk mengurangi *defect* berupa *missing value* sebanyak mungkin.
#
# Sebelum melakukan *merging*, perlu diperhatikan juga instruksi berikutnya:
# > Untuk *header* kolom menggunakan bentuk kecil semua dan isi data menggunakan huruf besar semua.
# * *Header* dari kolom yang akan digabungkan sudah dalam bentuk kecil atau *lowercase*, tetapi
# * Beberapa kolom seperti `nama_provinsi` dan `periode_update` dari `data_dinas_sosial` masih berisikan nilai dalam format *lowercase*, sehingga tahapan berikut akan mengubah formatnya menjadi *uppercase*:

# %%
# Mengubah isi dari tiap kolom menjadi uppercase
data_dinas_sosial['nama_provinsi'] = data_dinas_sosial['nama_provinsi'].str.upper()
data_dinas_sosial['periode_update'] = data_dinas_sosial['periode_update'].str.upper()

# %% [markdown]
# Juga ditemukan nilai pada *key* `kabupaten` yang tidak persis sama dengan `nama_kabupaten_kota`.
# * Hal ini dikarenakan isi dari `kabupaten` menggunakan format `KAB.` lalu diikuti dengan nama dari kabupaten tersebut.
# * Format ini pun perlu disesuaikan dengan mengikuti acuan dari `bentuk_table`:

# %%
# Mengganti tiap data pada kolom 'kabupaten'
data_dinas_sosial['kabupaten'] = data_dinas_sosial['kabupaten'].str.replace(
    pat='KAB.', # Data dengan pola yang ditentukan
    repl='KABUPATEN' # Diganti dengan pola berikut
)

# %% [markdown]
# ### Data Merging
# Setelah perbandingan dan penyesuaian pada tahapan sebelumnya dinilai memadai, berikutnya proses penggabungan kedua data dapat dilakukan:

# %%
# Menggabungkan data dengan 'database-style join'
table = pd.merge(
    left=data_dinas_sosial, # Data pertama/left yang akan digabungkan
    right=data_master_desa, # Dengan data kedua/right
    how='inner', # Menggunakan key dari left dan mempertahankan urutan dari key tersebut
    left_on=['nama_provinsi', 'kabupaten', 'kecamatan', 'kelurahan'], # Kolom dari left yang hendak digabungkan sebagai key
    right_on=['nama_provinsi', 'nama_kabupaten_kota', 'kemendagri_nama_kecamatan', 'kemendagri_desa_kelurahan'] # Dengan key dari right
)

table.head(
    n=5
)
# Out:
#    id  kode_provinsi_x nama_provinsi   periode_update               nik  \
# 0   1               35    JAWA TIMUR  TRIWULAN I 2024  3526060000000000
# 1   2               35    JAWA TIMUR  TRIWULAN I 2024  3526180000000000
# 2   3               35    JAWA TIMUR  TRIWULAN I 2024  3526190000000000
# 3   4               35    JAWA TIMUR  TRIWULAN I 2024  3526060000000000
# 4   5               35    JAWA TIMUR  TRIWULAN I 2024  3526140000000000
#
#            nama             alamat    provinsi            kabupaten kecamatan  \
# 0     ABD HALIM        DSN GLIMBUR  JAWA TIMUR  KABUPATEN BANGKALAN     GEGER
# 1   ABD. ROHMAN  DSN. REMBAH GALIS  JAWA TIMUR  KABUPATEN BANGKALAN     GALIS
# 2  ABDUS SYUKUR  DSN. BARAT SUMBER  JAWA TIMUR  KABUPATEN BANGKALAN     GALIS
# 3        ACHMAD         DSN POCONG  JAWA TIMUR  KABUPATEN BANGKALAN     GEGER
# 4  ACHMAD RIDOI     DSN. BANGGUMOK  JAWA TIMUR  KABUPATEN BANGKALAN    TRAGAH
#
#   kelurahan  tahun kategori jumlah satuan  kode_provinsi_y  \
# 0    LERPAK   2024        -      -      -               35
# 1     GALIS   2024        -      -      -               35
# 2   LONGKEK   2024        -      -      -               35
# 3    CAMPOR   2024        -      -      -               35
# 4    TRAGAH   2024        -      -      -               35
#
#    kode_kabupaten_kota  nama_kabupaten_kota  bps_kode_kecamatan  \
# 0                 3526  KABUPATEN BANGKALAN             3526140
# 1                 3526  KABUPATEN BANGKALAN             3526070
# 2                 3526  KABUPATEN BANGKALAN             3526070
# 3                 3526  KABUPATEN BANGKALAN             3526140
# 4                 3526  KABUPATEN BANGKALAN             3526090
#
#   bps_nama_kecamatan  bps_kode_desa_kelurahan bps_desa_kelurahan  \
# 0              GEGER               3526140002             LERPAK
# 1              GALIS               3526070004              GALIS
# 2              GALIS               3526070009            LONGKEK
# 3              GEGER               3526140006             CAMPOR
# 4             TRAGAH               3526090013             TRAGAH
#
#   kemendagri_kode_kecamatan kemendagri_nama_kecamatan  \
# 0                  35.26.06                     GEGER
# 1                  35.26.18                     GALIS
# 2                  35.26.18                     GALIS
# 3                  35.26.06                     GEGER
# 4                  35.26.14                    TRAGAH
#
#   kemendagri_kode_desa_kelurahan kemendagri_desa_kelurahan
# 0                  35.26.06.2005                    LERPAK
# 1                  35.26.18.2007                     GALIS
# 2                  35.26.18.2006                   LONGKEK
# 3                  35.26.06.2010                    CAMPOR
# 4                  35.26.14.2006                    TRAGAH

# %%
table.isna().sum()
# Out:
# id                                0
# kode_provinsi_x                   0
# nama_provinsi                     0
# periode_update                    0
# nik                               0
# nama                              0
# alamat                            0
# provinsi                          0
# kabupaten                         0
# kecamatan                         0
# kelurahan                         0
# tahun                             0
# kategori                          0
# jumlah                            0
# satuan                            0
# kode_provinsi_y                   0
# kode_kabupaten_kota               0
# nama_kabupaten_kota               0
# bps_kode_kecamatan                0
# bps_nama_kecamatan                0
# bps_kode_desa_kelurahan           0
# bps_desa_kelurahan                0
# kemendagri_kode_kecamatan         0
# kemendagri_nama_kecamatan         0
# kemendagri_kode_desa_kelurahan    0
# kemendagri_desa_kelurahan         0
# dtype: int64

# %%
def if_null(value, replace):
    if value is None or pd.isna(value):
        return replace
    return value

def apply_if_null(column_missing, column_filled):
    table[column_missing] = table[[column_missing, column_filled]]\
        .apply(lambda row: if_null(value=row[column_missing], replace=row[column_filled]), axis=1)

apply_if_null(column_missing='kode_provinsi_y', column_filled='kode_provinsi_x')
apply_if_null(column_missing='nama_kabupaten_kota', column_filled='kabupaten')
apply_if_null(column_missing='bps_nama_kecamatan', column_filled='kecamatan')
apply_if_null(column_missing='kemendagri_nama_kecamatan', column_filled='kecamatan')
apply_if_null(column_missing='bps_desa_kelurahan', column_filled='kelurahan')
apply_if_null(column_missing='kemendagri_desa_kelurahan', column_filled='kelurahan')

table.update(
    other=data_master_desa,
    overwrite=False
)

table
# Out:
#           id  kode_provinsi_x nama_provinsi     periode_update  \
# 0          1               35    JAWA TIMUR    TRIWULAN I 2024
# 1          2               35    JAWA TIMUR    TRIWULAN I 2024
# 2          3               35    JAWA TIMUR    TRIWULAN I 2024
# 3          4               35    JAWA TIMUR    TRIWULAN I 2024
# 4          5               35    JAWA TIMUR    TRIWULAN I 2024
# ...      ...              ...           ...                ...
# 11287  11579               35    JAWA TIMUR  TRIWULAN III 2024
# 11288  11580               35    JAWA TIMUR  TRIWULAN III 2024
# 11289  11581               35    JAWA TIMUR  TRIWULAN III 2024
# 11290  11582               35    JAWA TIMUR  TRIWULAN III 2024
# 11291  11583               35    JAWA TIMUR  TRIWULAN III 2024
#
#                     nik                  nama  \
# 0      3526060000000000             ABD HALIM
# 1      3526180000000000           ABD. ROHMAN
# 2      3526190000000000          ABDUS SYUKUR
# 3      3526060000000000                ACHMAD
# 4      3526140000000000          ACHMAD RIDOI
# ...                 ...                   ...
# 11287  3504060000000000  WARDATUL MUKHOYYAROH
# 11288  3504020000000000            WIJI UTAMI
# 11289  3504070000000000                  YENI
# 11290  3504190000000000               YULIANA
# 11291  3504030000000000    YUSRIL PRAJA MUKTI
#
#                                       alamat    provinsi  \
# 0                                DSN GLIMBUR  JAWA TIMUR
# 1                          DSN. REMBAH GALIS  JAWA TIMUR
# 2                          DSN. BARAT SUMBER  JAWA TIMUR
# 3                                 DSN POCONG  JAWA TIMUR
# 4                             DSN. BANGGUMOK  JAWA TIMUR
# ...                                      ...         ...
# 11287               DSN. BANCAAN RT 01 RW 01  JAWA TIMUR
# 11288            DUSUN RONGGANAN RT 03 RW 03  JAWA TIMUR
# 11289             DUSUN SELOGIRI RT 03 RW 04  JAWA TIMUR
# 11290                  DSN SODO RT 04/ RW 01  JAWA TIMUR
# 11291  JL. KHR ABDUL FATAH 4/2 RT 003 RW 001  JAWA TIMUR
#
#                    kabupaten   kecamatan    kelurahan  tahun kategori jumlah  \
# 0        KABUPATEN BANGKALAN       GEGER       LERPAK   2024        -      -
# 1        KABUPATEN BANGKALAN       GALIS        GALIS   2024        -      -
# 2        KABUPATEN BANGKALAN       GALIS      LONGKEK   2024        -      -
# 3        KABUPATEN BANGKALAN       GEGER       CAMPOR   2024        -      -
# 4        KABUPATEN BANGKALAN      TRAGAH       TRAGAH   2024        -      -
# ...                      ...         ...          ...    ...      ...    ...
# 11287  KABUPATEN TULUNGAGUNG      KAUMAN     MOJOSARI   2024        -      -
# 11288  KABUPATEN TULUNGAGUNG   BOYOLANGU  KENDALBULUR   2024        -      -
# 11289  KABUPATEN TULUNGAGUNG   PAGERWOJO       PENJOR   2024        -      -
# 11290  KABUPATEN TULUNGAGUNG       PAKEL         SODO   2024        -      -
# 11291  KABUPATEN TULUNGAGUNG  KEDUNGWARU   MANGUNSARI   2024        -      -
#
#       satuan  kode_provinsi_y  kode_kabupaten_kota    nama_kabupaten_kota  \
# 0          -               35                 3526    KABUPATEN BANGKALAN
# 1          -               35                 3526    KABUPATEN BANGKALAN
# 2          -               35                 3526    KABUPATEN BANGKALAN
# 3          -               35                 3526    KABUPATEN BANGKALAN
# 4          -               35                 3526    KABUPATEN BANGKALAN
# ...      ...              ...                  ...                    ...
# 11287      -               35                 3504  KABUPATEN TULUNGAGUNG
# 11288      -               35                 3504  KABUPATEN TULUNGAGUNG
# 11289      -               35                 3504  KABUPATEN TULUNGAGUNG
# 11290      -               35                 3504  KABUPATEN TULUNGAGUNG
# 11291      -               35                 3504  KABUPATEN TULUNGAGUNG
#
#        bps_kode_kecamatan bps_nama_kecamatan  bps_kode_desa_kelurahan  \
# 0                 3526140              GEGER               3526140002
# 1                 3526070              GALIS               3526070004
# 2                 3526070              GALIS               3526070009
# 3                 3526140              GEGER               3526140006
# 4                 3526090             TRAGAH               3526090013
# ...                   ...                ...                      ...
# 11287             3504160             KAUMAN               3504160009
# 11288             3504110          BOYOLANGU               3504110002
# 11289             3504180         PAGER WOJO               3504180005
# 11290             3504030              PAKEL               3504030007
# 11291             3504130         KEDUNGWARU               3504130010
#
#       bps_desa_kelurahan kemendagri_kode_kecamatan kemendagri_nama_kecamatan  \
# 0                 LERPAK                  35.26.06                     GEGER
# 1                  GALIS                  35.26.18                     GALIS
# 2                LONGKEK                  35.26.18                     GALIS
# 3                 CAMPOR                  35.26.06                     GEGER
# 4                 TRAGAH                  35.26.14                    TRAGAH
# ...                  ...                       ...                       ...
# 11287           MOJOSARI                  35.04.05                    KAUMAN
# 11288        KENDALBULUR                  35.04.02                 BOYOLANGU
# 11289             PENJOR                  35.04.06                 PAGERWOJO
# 11290               SODO                  35.04.18                     PAKEL
# 11291         MANGUNSARI                  35.04.03                KEDUNGWARU
#
#       kemendagri_kode_desa_kelurahan kemendagri_desa_kelurahan
# 0                      35.26.06.2005                    LERPAK
# 1                      35.26.18.2007                     GALIS
# 2                      35.26.18.2006                   LONGKEK
# 3                      35.26.06.2010                    CAMPOR
# 4                      35.26.14.2006                    TRAGAH
# ...                              ...                       ...
# 11287                  35.04.05.2008                  MOJOSARI
# 11288                  35.04.02.2006               KENDALBULUR
# 11289                  35.04.06.2006                    PENJOR
# 11290                  35.04.18.2007                      SODO
# 11291                  35.04.03.2014                MANGUNSARI
#
# [11292 rows x 26 columns]

# %% [markdown]
# **Observasi:**
# * Sesuai dengan hasil analisis pada bagian `Data Comparison` sebelumnya, `kode_provinsi` yang digunakan adalah `kode_provinsi_y` dan `kode_provinsi_x` tidak digunakan dalam tabel yang baru.
# * Nama dari beberapa kolom seperti `bps_desa_kelurahan`, `kemendagri_desa_kelurahan`, dan `kategori` perlu disesuaikan dengan format nama kolom yang digunakan pada `contoh_tabel`.
# * Pun demikian dengan urutan nama kolom pada `tabel` mengikuti urutan nama kolom `bentuk_table`

# %%
# # Menghapus kolom dari table
# table = table.drop(
#     columns=[
#         'kode_provinsi_x'
#     ]
# # Mengganti nama kolom sesuai format pada `bentuk_table`
# ).rename(
#     columns={
#         'bps_desa_kelurahan': 'bps_nama_desa_kelurahan',
#         'kemendagri_desa_kelurahan': 'kemendagri_nama_desa_kelurahan',
#         'kategori': 'kategori.1'
#     }
# # Mengatur urutan dari table 
# ).reindex(
#     labels=bentuk_table.columns, # Menggunakan daftar kolom dari 'bentuk_table'
#     axis=1 # 'Axis' kedua atau kolom yang diurutkan sesuai parameter 'labels' sebelumnya
# )

# %% [markdown]
# Hasil dari proses penggabungan ini berupa *variabel instance* `table` yang dapat dibandingkan dengan `bentuk_table`:

# %%
print('Table baru:')
display(
    table.head(
        n=3
    )
)

print('Contoh table:')
display(
    bentuk_table.head(
        n=3
    )
)
# Out:
# Table baru:
#    id  kode_provinsi_x nama_provinsi   periode_update               nik  \
# 0   1               35    JAWA TIMUR  TRIWULAN I 2024  3526060000000000
# 1   2               35    JAWA TIMUR  TRIWULAN I 2024  3526180000000000
# 2   3               35    JAWA TIMUR  TRIWULAN I 2024  3526190000000000
#
#            nama             alamat    provinsi            kabupaten kecamatan  \
# 0     ABD HALIM        DSN GLIMBUR  JAWA TIMUR  KABUPATEN BANGKALAN     GEGER
# 1   ABD. ROHMAN  DSN. REMBAH GALIS  JAWA TIMUR  KABUPATEN BANGKALAN     GALIS
# 2  ABDUS SYUKUR  DSN. BARAT SUMBER  JAWA TIMUR  KABUPATEN BANGKALAN     GALIS
#
#   kelurahan  tahun kategori jumlah satuan  kode_provinsi_y  \
# 0    LERPAK   2024        -      -      -               35
# 1     GALIS   2024        -      -      -               35
# 2   LONGKEK   2024        -      -      -               35
#
#    kode_kabupaten_kota  nama_kabupaten_kota  bps_kode_kecamatan  \
# 0                 3526  KABUPATEN BANGKALAN             3526140
# 1                 3526  KABUPATEN BANGKALAN             3526070
# 2                 3526  KABUPATEN BANGKALAN             3526070
#
#   bps_nama_kecamatan  bps_kode_desa_kelurahan bps_desa_kelurahan  \
# 0              GEGER               3526140002             LERPAK
# 1              GALIS               3526070004              GALIS
# 2              GALIS               3526070009            LONGKEK
#
#   kemendagri_kode_kecamatan kemendagri_nama_kecamatan  \
# 0                  35.26.06                     GEGER
# 1                  35.26.18                     GALIS
# 2                  35.26.18                     GALIS
#
#   kemendagri_kode_desa_kelurahan kemendagri_desa_kelurahan
# 0                  35.26.06.2005                    LERPAK
# 1                  35.26.18.2007                     GALIS
# 2                  35.26.18.2006                   LONGKEK
# Contoh table:
#    id  kode_provinsi_y nama_provinsi  kode_kabupaten_kota  \
# 0   1               35    JAWA TIMUR                 3526
# 1   2               35    JAWA TIMUR                 3526
# 2   3               35    JAWA TIMUR                 3526
#
#              kabupaten  nama_kabupaten_kota  bps_kode_kecamatan kecamatan  \
# 0  KABUPATEN BANGKALAN  KABUPATEN BANGKALAN             3526140     GEGER
# 1  KABUPATEN BANGKALAN  KABUPATEN BANGKALAN             3526070     GALIS
# 2  KABUPATEN BANGKALAN  KABUPATEN BANGKALAN             3526070     GALIS
#
#   bps_nama_kecamatan  bps_kode_desa_kelurahan kelurahan  \
# 0              GEGER               3526140002    LERPAK
# 1              GALIS               3526070004     GALIS
# 2              GALIS               3526070009   LONGKEK
#
#   bps_nama_desa_kelurahan kemendagri_kode_kecamatan kemendagri_nama_kecamatan  \
# 0                  LERPAK                  35.26.06                     GEGER
# 1                   GALIS                  35.26.18                     GALIS
# 2                 LONGKEK                  35.26.18                     GALIS
#
#   kemendagri_kode_desa_kelurahan kemendagri_nama_desa_kelurahan  \
# 0                  35.26.06.2005                         LERPAK
# 1                  35.26.18.2007                          GALIS
# 2                  35.26.18.2006                        LONGKEK
#
#     periode_update               nik          nama             alamat  \
# 0  TRIWULAN I 2024  3526060000000000     ABD HALIM        DSN GLIMBUR
# 1  TRIWULAN I 2024  3526180000000000   ABD. ROHMAN  DSN. REMBAH GALIS
# 2  TRIWULAN I 2024  3526190000000000  ABDUS SYUKUR  DSN. BARAT SUMBER
#
#    kategori kategori.1 jumlah satuan  tahun
# 0       NaN          -      -      -   2024
# 1       NaN          -      -      -   2024
# 2       NaN          -      -      -   2024

# %% [markdown]
# **Observasi:**
# * Secara keseluruhan —mulai dari urutan dan nama kolom, isi, serta bentuk dari data— dapat dinyatakan bahwa `table` yang dibentuk telah menyerupai unsur-unsur yang dicontohkan dalam `bentuk_table`.
# * Terkecuali isi dari kolom `kode_kabupaten_kota`, `bps_kode_kecamatan`, dan `bps_kode_desa_kelurahan` pada `table` yang memiliki sedikit perbedaan pada nilai dan format yang digunakan.
# * Tahapan analisis berikutnya akan meninjau penyebab dan letak dari perbedaan ini.

# %% [markdown]
# ---
# ## 2 | *Check Null*

# %% [markdown]
# > Lakukan *check* pada data tersebut, apakah ada kolom (dengan) nilai *null* atau tidak.

# %%
pd.DataFrame(
    data=table\
        # Mendeteksi missing value (NA) pada tiap kolom dalam table
        .isna()\
            # Kemudian menghitung jumlah missing value tersebut
            .sum(),
# Mengganti nama kolom untuk memudahkan pemahaman
).rename(
    columns={0: 'NA (n)'}
)
# Out:
#                                 NA (n)
# id                                   0
# kode_provinsi_x                      0
# nama_provinsi                        0
# periode_update                       0
# nik                                  0
# nama                                 0
# alamat                               0
# provinsi                             0
# kabupaten                            0
# kecamatan                            0
# kelurahan                            0
# tahun                                0
# kategori                             0
# jumlah                               0
# satuan                               0
# kode_provinsi_y                      0
# kode_kabupaten_kota                  0
# nama_kabupaten_kota                  0
# bps_kode_kecamatan                   0
# bps_nama_kecamatan                   0
# bps_kode_desa_kelurahan              0
# bps_desa_kelurahan                   0
# kemendagri_kode_kecamatan            0
# kemendagri_nama_kecamatan            0
# kemendagri_kode_desa_kelurahan       0
# kemendagri_desa_kelurahan            0

# %%
table = table.drop(
    columns='kategori'
).rename(
    columns={
        'kategori.1': 'kategori'
    }
)

# %%
table[table.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [id, kode_provinsi_x, nama_provinsi, periode_update, nik, nama, alamat, provinsi, kabupaten, kecamatan, kelurahan, tahun, jumlah, satuan, kode_provinsi_y, kode_kabupaten_kota, nama_kabupaten_kota, bps_kode_kecamatan, bps_nama_kecamatan, bps_kode_desa_kelurahan, bps_desa_kelurahan, kemendagri_kode_kecamatan, kemendagri_nama_kecamatan, kemendagri_kode_desa_kelurahan, kemendagri_desa_kelurahan]
# Index: []

# %% [markdown]
# ---
# ## 3 | *Data Cleansing*

# %% [markdown]
# > Jika ada nilai null lakukan cleansing data pada table yang sudah dilakukan join sehingga meminimalisir nilai null.

# %% [markdown]
# ---
# ## 4 | *Addendum*
#
# > Buatlah coding cleansing dengan bahasa python. Asumsikan akan melakukan cleansing data pada data yang jumlahnya besar dan beragam sehingga buatlah algoritma coding yang bisa digunakan untuk banyak case data.
#
# > Buatlah penjelasan cleansing data yang Anda lakukan dari problem dan solusi yang diberikan.
#
# > Untuk coding python mohon kumpulkan file dalam bentuk file python (.ipynb) dan untuk analysisnya boleh dalam bentuk word atau di file python tersebut.
#
# > "Syarat dan ketentuan tugas: Buatlah dalam format PPT (canva/google slide) maksimal 15 slides. Kirimkan link PPT/drive ke gform Pendaftaran Magang Mandiri SEAL Batch 2 2025 Batas maksimal pengumpulan 3 hari
